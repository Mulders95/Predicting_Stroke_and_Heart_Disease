# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
stroke_df = pd.read_csv("Stroke/stroke_dataset_for_modeling.csv")
stroke_df
# Out:
#            age  avg_glucose_level  heart_risk  stroke
# 0     0.763532           2.312038           1       1
# 1     0.343728           1.787070           0       1
# 2     1.673108          -0.121883           1       1
# 3    -0.495881           1.172891           0       1
# 4     1.603141           1.230185           1       1
# ...        ...                ...         ...     ...
# 3408  1.673108          -0.561404           1       0
# 3409  1.743076           0.260344           0       0
# 3410 -1.475424          -0.576471           0       0
# 3411 -0.355946           1.074955           0       0
# 3412 -0.845718          -0.531072           0       0
#
# [3413 rows x 4 columns]

# %%
# Sets of indices where stroke and heart risk are present
A = set(stroke_df[stroke_df['stroke'] == 1].index)
B = set(stroke_df[stroke_df['heart_risk'] == 1].index)

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn2_unweighted([A, B], set_labels=('Stroke', 'Heart Risk'), set_colors=("green", "blue"), alpha=0.6)
plt.title("Stroke and Heart Risk Venn Diagram", fontweight="bold", fontsize=14, y = 0.94)
plt.show()

# %%
heartdisease_df = pd.read_csv("HeartDisease/heartdisease_data_for_visual.csv")
heartdisease_df
# Out:
#       gender   age      work_type   smoking_status  stroke_risk  \
# 0       Male  67.0        Private  formerly smoked            1
# 1     Female  61.0  Self-employed     never smoked            1
# 2       Male  80.0        Private     never smoked            1
# 3     Female  49.0        Private           smokes            1
# 4     Female  79.0  Self-employed     never smoked            1
# ...      ...   ...            ...              ...          ...
# 3599  Female  80.0        Private     never smoked            1
# 3600  Female  81.0  Self-employed     never smoked            0
# 3601  Female  35.0  Self-employed     never smoked            0
# 3602    Male  51.0        Private  formerly smoked            0
# 3603  Female  44.0       Govt_job          Unknown            0
#
#       heart_disease  age.1  avg_glucose_level
# 0                 1   67.0             228.69
# 1                 0   61.0             202.21
# 2                 1   80.0             105.92
# 3                 0   49.0             171.23
# 4                 0   79.0             174.12
# ...             ...    ...                ...
# 3599              0   80.0              83.75
# 3600              0   81.0             125.20
# 3601              0   35.0              82.99
# 3602              0   51.0             166.29
# 3603              0   44.0              85.28
#
# [3604 rows x 8 columns]

# %%
# Sets of indices where stroke and heart risk are present
A = set(heartdisease_df[heartdisease_df['heart_disease'] == 1].index)
B = set(heartdisease_df[heartdisease_df['stroke_risk'] == 1].index)

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn2_unweighted([A, B], set_labels=('Heart Disease', 'Stroke Risk'), set_colors=("green", "blue"), alpha=0.6)
plt.title("Heart Disease and Stroke Risk Venn Diagram", fontweight="bold", fontsize=14, y = 0.94)
plt.show()
# Out:
# c:\Users\15199\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib_venn\_util.py:32: UserWarning: venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.
#   warnings.warn(
